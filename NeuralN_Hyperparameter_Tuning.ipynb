# %%
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
dataset = np.loadtxt("/content/pima-indians-diabetes.data.csv", delimiter=",")
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2             3             4  \
# count  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02
# mean  -8.789266e-17 -9.251859e-18  1.503427e-17  8.211024e-17 -4.972874e-17
# std    1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00 -3.572597e+00 -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01 -3.673367e-01 -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01  1.496408e-01  1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01  5.632228e-01  7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00  2.734528e+00  4.921866e+00  6.652839e+00
#
#                   5             6             7
# count  7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.960595e-15  1.905883e-15  2.081668e-16
# std    1.000652e+00  1.000652e+00  1.000652e+00
# min   -4.060474e+00 -1.189553e+00 -1.041549e+00
# 25%   -5.955785e-01 -6.889685e-01 -7.862862e-01
# 50%    9.419788e-04 -3.001282e-01 -3.608474e-01
# 75%    5.847705e-01  4.662269e-01  6.602056e-01
# max    4.455807e+00  5.883565e+00  4.063716e+00

# %% [markdown]
# **Tuning of Hyperparameters :- **

# %%
# create NN and find best batch size and best epchs
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential # In NN we are going to add components (i.e. hidden layers) one by one in sequential manner
from keras.layers import Dense # the no. of neurons
from keras.wrappers.scikit_learn import KerasClassifier

from tensorflow.keras.optimizers import Adam # Adam - Adaptive Momentum - is an optimizer

# %%
# create model
def create_model():
    model = Sequential()
    #below is the first hidden layer
    model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
    #Dense is a NN, 12 - no. of neurons, i/p - 8 columns, kernel_initializer=uniform - bias or weights can be taken from uniform distribution.
    #below is the second hidden layer
    model.add(Dense(8,kernel_initializer='uniform', activation='relu'))
    #below is the output layer
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

    adam=Adam(learning_rate=0.01) # Adam is the optimizer from stochastic Gradient descent variant, lr - learning rate - eta
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    # using binary cross entropy find accuracy of model
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0) # verbose=0 means don't print any information on screen
# Define the grid search parameters
batch_size = [10,20,40] # out of these 3 which is best value that we need to find using accuracy
# model will be built using 10 batch size once, then 20, then 40
epochs = [10,50,100,150] # makes all combinations all batch size and epochs
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10) # by default it takes 5 K folds, verbose =10: displays 10 lines of epochs 1/12 for 10 times
grid_result = grid.fit(X_standardized,y)
# batch size=3, epoch=4. 3*4=12, 12*5 folds = 60 models will be built
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START batch_size=10, epochs=10...................................
# [CV 1/5; 1/12] END ....batch_size=10, epochs=10;, score=0.727 total time=   2.9s
# [CV 2/5; 1/12] START batch_size=10, epochs=10...................................
# [CV 2/5; 1/12] END ....batch_size=10, epochs=10;, score=0.714 total time=   2.1s
# [CV 3/5; 1/12] START batch_size=10, epochs=10...................................
# [CV 3/5; 1/12] END ....batch_size=10, epochs=10;, score=0.766 total time=   2.1s
# [CV 4/5; 1/12] START batch_size=10, epochs=10...................................
# [CV 4/5; 1/12] END ....batch_size=10, epochs=10;, score=0.837 total time=   2.8s
# [CV 5/5; 1/12] START batch_size=10, epochs=10...................................
# [CV 5/5; 1/12] END ....batch_size=10, epochs=10;, score=0.778 total time=   2.6s
# [CV 1/5; 2/12] START batch_size=10, epochs=50...................................
# [CV 1/5; 2/12] END ....batch_size=10, epochs=50;, score=0.740 total time=   5.8s
# [CV 2/5; 2/12] START batch_size=10, epochs=50...................................
# [CV 2/5; 2/12] END ....batch_size=10, epochs=50;, score=0.701 total time=   7.0s
# [CV 3/5; 2/12] START batch_size=10, epochs=50...................................
# [CV 3/5; 2/12] END ....batch_size=10, epochs=50;, score=0.779 total time=   6.2s
# [CV 4/5; 2/12] START batch_size=10, epochs=50...................................
# [CV 4/5; 2/12] END ....batch_size=10, epochs=50;, score=0.778 total time=  11.3s
# [CV 5/5; 2/12] START batch_size=10, epochs=50...................................
# [CV 5/5; 2/12] END ....batch_size=10, epochs=50;, score=0.745 total time=   6.1s
# [CV 1/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 1/5; 3/12] END ...batch_size=10, epochs=100;, score=0.734 total time=  11.7s
# [CV 2/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 2/5; 3/12] END ...batch_size=10, epochs=100;, score=0.675 total time=  11.4s
# [CV 3/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 3/5; 3/12] END ...batch_size=10, epochs=100;, score=0.812 total time=  11.6s
# [CV 4/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 4/5; 3/12] END ...batch_size=10, epochs=100;, score=0.784 total time=  21.6s
# [CV 5/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 5/5; 3/12] END ...batch_size=10, epochs=100;, score=0.765 total time=  11.5s
# [CV 1/5; 4/12] START batch_size=10, epochs=150..................................
# [CV 1/5; 4/12] END ...batch_size=10, epochs=150;, score=0.734 total time=  17.2s
# [CV 2/5; 4/12] START batch_size=10, epochs=150..................................
# [CV 2/5; 4/12] END ...batch_size=10, epochs=150;, score=0.688 total time=  21.7s
# [CV 3/5; 4/12] START batch_size=10, epochs=150..................................
# [CV 3/5; 4/12] END ...batch_size=10, epochs=150;, score=0.753 total time=  21.9s
# [CV 4/5; 4/12] START batch_size=10, epochs=150..................................
# [CV 4/5; 4/12] END ...batch_size=10, epochs=150;, score=0.778 total time=  16.3s
# [CV 5/5; 4/12] START batch_size=10, epochs=150..................................
# [CV 5/5; 4/12] END ...batch_size=10, epochs=150;, score=0.778 total time=  17.4s
# [CV 1/5; 5/12] START batch_size=20, epochs=10...................................
# [CV 1/5; 5/12] END ....batch_size=20, epochs=10;, score=0.734 total time=   1.7s
# [CV 2/5; 5/12] START batch_size=20, epochs=10...................................
# [CV 2/5; 5/12] END ....batch_size=20, epochs=10;, score=0.708 total time=   1.5s
# [CV 3/5; 5/12] START batch_size=20, epochs=10...................................
# [CV 3/5; 5/12] END ....batch_size=20, epochs=10;, score=0.766 total time=   1.7s
# [CV 4/5; 5/12] START batch_size=20, epochs=10...................................
# [CV 4/5; 5/12] END ....batch_size=20, epochs=10;, score=0.856 total time=   1.7s
# [CV 5/5; 5/12] START batch_size=20, epochs=10...................................
# [CV 5/5; 5/12] END ....batch_size=20, epochs=10;, score=0.758 total time=   1.7s
# [CV 1/5; 6/12] START batch_size=20, epochs=50...................................
# [CV 1/5; 6/12] END ....batch_size=20, epochs=50;, score=0.740 total time=   6.2s
# [CV 2/5; 6/12] START batch_size=20, epochs=50...................................
# [CV 2/5; 6/12] END ....batch_size=20, epochs=50;, score=0.708 total time=   3.6s
# [CV 3/5; 6/12] START batch_size=20, epochs=50...................................
# [CV 3/5; 6/12] END ....batch_size=20, epochs=50;, score=0.760 total time=   3.6s
# [CV 4/5; 6/12] START batch_size=20, epochs=50...................................
# [CV 4/5; 6/12] END ....batch_size=20, epochs=50;, score=0.830 total time=   5.2s
# [CV 5/5; 6/12] START batch_size=20, epochs=50...................................
# [CV 5/5; 6/12] END ....batch_size=20, epochs=50;, score=0.752 total time=   6.2s
# [CV 1/5; 7/12] START batch_size=20, epochs=100..................................
# [CV 1/5; 7/12] END ...batch_size=20, epochs=100;, score=0.727 total time=  11.3s
# [CV 2/5; 7/12] START batch_size=20, epochs=100..................................
# [CV 2/5; 7/12] END ...batch_size=20, epochs=100;, score=0.701 total time=   6.4s
# [CV 3/5; 7/12] START batch_size=20, epochs=100..................................
# [CV 3/5; 7/12] END ...batch_size=20, epochs=100;, score=0.753 total time=   7.0s
# [CV 4/5; 7/12] START batch_size=20, epochs=100..................................
# [CV 4/5; 7/12] END ...batch_size=20, epochs=100;, score=0.758 total time=   6.3s
# [CV 5/5; 7/12] START batch_size=20, epochs=100..................................
# [CV 5/5; 7/12] END ...batch_size=20, epochs=100;, score=0.745 total time=  11.7s
# [CV 1/5; 8/12] START batch_size=20, epochs=150..................................
# [CV 1/5; 8/12] END ...batch_size=20, epochs=150;, score=0.714 total time=   9.7s
# [CV 2/5; 8/12] START batch_size=20, epochs=150..................................
# [CV 2/5; 8/12] END ...batch_size=20, epochs=150;, score=0.675 total time=  11.3s
# [CV 3/5; 8/12] START batch_size=20, epochs=150..................................
# [CV 3/5; 8/12] END ...batch_size=20, epochs=150;, score=0.786 total time=   9.1s
# [CV 4/5; 8/12] START batch_size=20, epochs=150..................................
# [CV 4/5; 8/12] END ...batch_size=20, epochs=150;, score=0.784 total time=  11.7s
# [CV 5/5; 8/12] START batch_size=20, epochs=150..................................
# [CV 5/5; 8/12] END ...batch_size=20, epochs=150;, score=0.732 total time=  11.6s
# [CV 1/5; 9/12] START batch_size=40, epochs=10...................................
# [CV 1/5; 9/12] END ....batch_size=40, epochs=10;, score=0.753 total time=   1.9s
# [CV 2/5; 9/12] START batch_size=40, epochs=10...................................
# [CV 2/5; 9/12] END ....batch_size=40, epochs=10;, score=0.714 total time=   2.1s
# [CV 3/5; 9/12] START batch_size=40, epochs=10...................................
# [CV 3/5; 9/12] END ....batch_size=40, epochs=10;, score=0.747 total time=   1.9s
# [CV 4/5; 9/12] START batch_size=40, epochs=10...................................
# [CV 4/5; 9/12] END ....batch_size=40, epochs=10;, score=0.850 total time=   1.4s
# [CV 5/5; 9/12] START batch_size=40, epochs=10...................................
# [CV 5/5; 9/12] END ....batch_size=40, epochs=10;, score=0.771 total time=   1.4s
# [CV 1/5; 10/12] START batch_size=40, epochs=50..................................
# [CV 1/5; 10/12] END ...batch_size=40, epochs=50;, score=0.721 total time=   3.7s
# [CV 2/5; 10/12] START batch_size=40, epochs=50..................................
# [CV 2/5; 10/12] END ...batch_size=40, epochs=50;, score=0.714 total time=   3.7s
# [CV 3/5; 10/12] START batch_size=40, epochs=50..................................
# [CV 3/5; 10/12] END ...batch_size=40, epochs=50;, score=0.734 total time=   3.4s
# [CV 4/5; 10/12] START batch_size=40, epochs=50..................................
# [CV 4/5; 10/12] END ...batch_size=40, epochs=50;, score=0.824 total time=   2.5s
# [CV 5/5; 10/12] START batch_size=40, epochs=50..................................
# [CV 5/5; 10/12] END ...batch_size=40, epochs=50;, score=0.765 total time=   3.6s
# [CV 1/5; 11/12] START batch_size=40, epochs=100.................................
# [CV 1/5; 11/12] END ..batch_size=40, epochs=100;, score=0.760 total time=   4.0s
# [CV 2/5; 11/12] START batch_size=40, epochs=100.................................
# [CV 2/5; 11/12] END ..batch_size=40, epochs=100;, score=0.740 total time=   4.6s
# [CV 3/5; 11/12] START batch_size=40, epochs=100.................................
# [CV 3/5; 11/12] END ..batch_size=40, epochs=100;, score=0.766 total time=   6.7s
# [CV 4/5; 11/12] START batch_size=40, epochs=100.................................
# [CV 4/5; 11/12] END ..batch_size=40, epochs=100;, score=0.752 total time=   6.3s
# [CV 5/5; 11/12] START batch_size=40, epochs=100.................................
# [CV 5/5; 11/12] END ..batch_size=40, epochs=100;, score=0.778 total time=   4.0s
# [CV 1/5; 12/12] START batch_size=40, epochs=150.................................
# [CV 1/5; 12/12] END ..batch_size=40, epochs=150;, score=0.747 total time=   5.5s
# [CV 2/5; 12/12] START batch_size=40, epochs=150.................................
# [CV 2/5; 12/12] END ..batch_size=40, epochs=150;, score=0.734 total time=   6.6s
# [CV 3/5; 12/12] START batch_size=40, epochs=150.................................
# [CV 3/5; 12/12] END ..batch_size=40, epochs=150;, score=0.766 total time=   6.3s
# [CV 4/5; 12/12] START batch_size=40, epochs=150.................................
# [CV 4/5; 12/12] END ..batch_size=40, epochs=150;, score=0.810 total time=   6.6s
# [CV 5/5; 12/12] START batch_size=40, epochs=150.................................
# [CV 5/5; 12/12] END ..batch_size=40, epochs=150;, score=0.765 total time=   6.2s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7670401573181153, using {'batch_size': 40, 'epochs': 10}
# 0.7644342660903931,0.043093444733982876 with: {'batch_size': 10, 'epochs': 10}
# 0.7487310171127319,0.02866399623253584 with: {'batch_size': 10, 'epochs': 50}
# 0.7539597749710083,0.04682025592049717 with: {'batch_size': 10, 'epochs': 100}
# 0.7461760520935059,0.03331552464513433 with: {'batch_size': 10, 'epochs': 150}
# 0.7644342660903931,0.050227400030165785 with: {'batch_size': 20, 'epochs': 10}
# 0.7578983187675477,0.0401807340668268 with: {'batch_size': 20, 'epochs': 50}
# 0.7370172381401062,0.020721491550990796 with: {'batch_size': 20, 'epochs': 100}
# 0.7383329153060914,0.04230203038651627 with: {'batch_size': 20, 'epochs': 150}
# 0.7670401573181153,0.04523432690167328 with: {'batch_size': 40, 'epochs': 10}
# 0.7514133095741272,0.040014368148913036 with: {'batch_size': 40, 'epochs': 50}
# 0.7591291069984436,0.012734609095455809 with: {'batch_size': 40, 'epochs': 100}
# 0.764383339881897,0.025979159725513203 with: {'batch_size': 40, 'epochs': 150}

# %%
params
# Out:
# [{'batch_size': 10, 'epochs': 10},
#  {'batch_size': 10, 'epochs': 50},
#  {'batch_size': 10, 'epochs': 100},
#  {'batch_size': 10, 'epochs': 150},
#  {'batch_size': 20, 'epochs': 10},
#  {'batch_size': 20, 'epochs': 50},
#  {'batch_size': 20, 'epochs': 100},
#  {'batch_size': 20, 'epochs': 150},
#  {'batch_size': 40, 'epochs': 10},
#  {'batch_size': 40, 'epochs': 50},
#  {'batch_size': 40, 'epochs': 100},
#  {'batch_size': 40, 'epochs': 150}]

# %% [markdown]
# ## Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout
# drop out rate - to control the accuracy. To overcome overfit of model randomly remove connection of some neurons
# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(12,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))

    adam = Adam(learning_rate = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters: Learning rate and dropout rate are the hyperparameters we want to test

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]# drop 0%,10%, 20% neurons

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10) # total 9*5 default folds=45 models will be built. (Lrate 3 values, Dropout rate =3, 3*3=9,)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 1/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.760 total time=   1.8s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 2/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.714 total time=   1.4s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 3/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.760 total time=   1.4s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 4/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.824 total time=   2.0s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 5/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.765 total time=   1.5s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 1/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.747 total time=   1.4s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 2/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.675 total time=   2.3s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 3/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.760 total time=   1.8s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 4/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.830 total time=   1.4s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 5/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.784 total time=   1.4s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 1/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.760 total time=   1.4s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 2/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.688 total time=   1.4s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 3/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.747 total time=   1.3s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 4/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.837 total time=   1.4s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 5/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.745 total time=   1.8s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 1/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.760 total time=   2.9s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 2/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.701 total time=   1.9s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 3/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.773 total time=   1.5s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 4/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.843 total time=   1.5s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 5/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.771 total time=   1.9s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 1/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.734 total time=   1.5s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 2/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.727 total time=   1.6s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 3/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.753 total time=   2.3s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 4/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.837 total time=   1.6s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 5/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.739 total time=   1.5s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 1/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.740 total time=   1.5s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 2/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.656 total time=   1.5s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 3/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.747 total time=   2.4s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 4/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.837 total time=   1.6s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 5/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.732 total time=   2.2s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 1/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.760 total time=   2.3s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 2/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.701 total time=   1.5s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 3/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.747 total time=   1.5s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 4/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.817 total time=   1.6s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 5/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.745 total time=   1.5s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 1/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.753 total time=   1.5s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 2/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.701 total time=   1.5s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 3/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.760 total time=   2.1s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 4/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.824 total time=   2.2s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 5/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.752 total time=   2.2s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 1/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.721 total time=   1.6s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 2/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.695 total time=   1.5s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 3/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.766 total time=   1.5s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 4/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.837 total time=   1.5s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 5/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.765 total time=   1.9s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))

# %% [markdown]
# ## Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.2))
    model.add(Dense(12,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.2))
    model.add(Dense(1,activation = 'sigmoid'))

    adam = Adam(learning_rate = 0.01)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model
    # In machine learning, Loss function is used to find error or deviation in the learning process.
    # Keras requires loss function during model compilation process. https://www.tutorialspoint.com/keras/keras_model_compilation.htm

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 50)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear'] # find which activation function is best out of these
init = ['uniform','normal','zero'] # Weight initializers from where the weights has to be sampled randomly. Uniform distribution, normal distribution and zero distribution

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))

# %% [markdown]
# ## Tuning of Hyperparameter :-Number of Neurons in hidden layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'linear'))
    model.add(Dropout(0.2))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'linear'))
    model.add(Dropout(0.2))
    model.add(Dense(1,activation = 'sigmoid'))

    adam = Adam(learning_rate = 0.01)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 50)

# Define the grid search parameters

neuron1 = [4,8,16]# in first hidden layer use 4,8,16 neurons
neuron2 = [2,4,8]# in second hidden layer use 2,4,8 neurons

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.760 total time=   3.0s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.740 total time=   2.7s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.766 total time=   2.6s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.830 total time=   3.8s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.739 total time=   3.1s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.779 total time=   3.4s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.727 total time=   3.8s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.773 total time=   3.9s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.824 total time=   2.7s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.765 total time=   3.7s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.773 total time=   3.8s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.721 total time=   4.1s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.766 total time=   3.7s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.824 total time=   3.7s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.745 total time=   3.8s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.786 total time=   4.0s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.727 total time=   2.6s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.779 total time=   3.4s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.824 total time=   4.0s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.771 total time=   2.8s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.779 total time=   3.8s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.734 total time=   3.7s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.753 total time=   3.6s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.830 total time=   3.7s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.758 total time=   2.7s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.779 total time=   3.8s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.714 total time=   3.6s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.760 total time=   3.7s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.824 total time=   3.7s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.784 total time=   4.0s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.766 total time=   4.3s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.714 total time=   3.8s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.760 total time=   3.9s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.824 total time=   3.6s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.758 total time=   2.7s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.766 total time=   3.8s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.708 total time=   2.6s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.760 total time=   3.7s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.830 total time=   2.7s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.765 total time=   2.7s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.773 total time=   2.6s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.714 total time=   4.6s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.766 total time=   3.0s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.830 total time=   2.7s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.771 total time=   2.7s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7773958086967468, using {'neuron1': 8, 'neuron2': 2}
# 0.7669722437858582,0.033329513017886676 with: {'neuron1': 4, 'neuron2': 2}
# 0.7734912157058715,0.030823893138293236 with: {'neuron1': 4, 'neuron2': 4}
# 0.7656735420227051,0.0341649544092364 with: {'neuron1': 4, 'neuron2': 8}
# 0.7773958086967468,0.03082541136700629 with: {'neuron1': 8, 'neuron2': 2}
# 0.7708938121795654,0.03293139218349116 with: {'neuron1': 8, 'neuron2': 4}
# 0.7722179770469666,0.035609128049830796 with: {'neuron1': 8, 'neuron2': 8}
# 0.764391815662384,0.034847145479469106 with: {'neuron1': 16, 'neuron2': 2}
# 0.7657074928283691,0.03881495371444925 with: {'neuron1': 16, 'neuron2': 4}
# 0.7709107875823975,0.03669044960874866 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# # Hyperparameters all at once

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))

    adam = Adam(learning_rate = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
# [CV 1/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-2fec94b5e23f> in <cell line: 36>()
#      34
#      35 grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
# ---> 36 grid_result = grid.fit(X_standardized,y)
#      37
#      38 # Summarize the results
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     862                 return False
#     863             else:
# --> 864                 self._dispatch(tasks)
#     865                 return True
#     866
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.9/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.9/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in __call__(self)
#     261         # change the default number of processes to -1
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263             return [func(*args, **kwargs)
#     264                     for func, args, kwargs in self.items]
#     265
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     261         # change the default number of processes to -1
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263             return [func(*args, **kwargs)
#     264                     for func, args, kwargs in self.items]
#     265
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# /usr/local/lib/python3.9/dist-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     246             raise ValueError("Invalid shape for y: " + str(y.shape))
#     247         self.n_classes_ = len(self.classes_)
# --> 248         return super().fit(x, y, **kwargs)
#     249
#     250     def predict(self, x, **kwargs):
#
# /usr/local/lib/python3.9/dist-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     173         fit_args.update(kwargs)
#     174
# --> 175         history = self.model.fit(x, y, **fit_args)
#     176
#     177         return history
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     140     with self._lock:
#     141       (concrete_function,
# --> 142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#     143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _maybe_define_function(self, args, kwargs)
#     340     """
#     341     args, kwargs, filtered_flat_args = (
# --> 342         self._function_spec.canonicalize_function_inputs(args, kwargs))
#     343
#     344     if self.input_signature is not None:
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/function_spec.py in canonicalize_function_inputs(self, args, kwargs)
#     406       args, kwargs = _convert_variables_to_tensors(args, kwargs)
#     407     args, kwargs = self.bind_function_inputs(args, kwargs)
# --> 408     args, kwargs = cast_inputs(args, kwargs, self.input_signature)
#     409     filtered_flat_args = filter_function_inputs(args, kwargs)
#     410
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/function_spec.py in cast_inputs(args, kwargs, input_signature)
#     478   """Casts args, kwargs to TF values based on an optional input_signature."""
#     479   if input_signature is None:
# --> 480     args = cast_numpy_inputs(args)
#     481   else:
#     482     args = cast_inputs_to_signature(args, input_signature)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/function_spec.py in cast_numpy_inputs(inputs)
#     488 def cast_numpy_inputs(inputs):
#     489   """Converts numpy array inputs to tensors."""
# --> 490   flat_inputs = composite_tensor_utils.flatten_with_variables(inputs)
#     491
#     492   # Check for NumPy arrays in arguments and convert them to Tensors.
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/composite_tensor_utils.py in flatten_with_variables(inputs)
#      33     if (isinstance(value, composite_tensor.CompositeTensor) and
#      34         not _pywrap_utils.IsResourceVariable(value)):
# ---> 35       components = value._type_spec._to_components(value)  # pylint: disable=protected-access
#      36       flat_inputs.extend(flatten_with_variables(components))
#      37     else:
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _type_spec(self)
#     791   @property
#     792   def _type_spec(self):
# --> 793     return IteratorSpec(self.element_spec)
#     794
#     795   def __next__(self):
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/data/ops/iterator_ops.py in element_spec(self)
#     845   @property
#     846   def element_spec(self):
# --> 847     return self._element_spec
#     848
#     849   def get_next(self):
#
# KeyboardInterrupt:
